# %%
import tensorflow_hub as hub

# %%
module = hub.Module("https://tfhub.dev/google/imagenet/inception_v2/feature_vector/1")
#height, width = hub.get_expected_image_size(module)
#images = ...  # A batch of images with shape [batch_size, height, width, 3].
#features = module(images)  # Features with shape [batch_size, num_features].
# Out:
# INFO:tensorflow:Using /var/folders/jd/x3k719kx32gdj073pj341h2c0000gn/T/tfhub_modules to cache modules.
# INFO:tensorflow:Downloading TF-Hub Module 'https://tfhub.dev/google/imagenet/inception_v2/feature_vector/1'.
# INFO:tensorflow:Downloaded TF-Hub Module 'https://tfhub.dev/google/imagenet/inception_v2/feature_vector/1'.
# INFO:tensorflow:Initialize variable module/InceptionV2/Conv2d_1a_7x7/biases:0 from checkpoint b'/var/folders/jd/x3k719kx32gdj073pj341h2c0000gn/T/tfhub_modules/deef2cd0f25a4e110230dfbfd9d93e785e6d9e9d/variables/variables' with InceptionV2/Conv2d_1a_7x7/biases
# INFO:tensorflow:Initialize variable module/InceptionV2/Conv2d_1a_7x7/depthwise_weights:0 from checkpoint b'/var/folders/jd/x3k719kx32gdj073pj341h2c0000gn/T/tfhub_modules/deef2cd0f25a4e110230dfbfd9d93e785e6d9e9d/variables/variables' with InceptionV2/Conv2d_1a_7x7/depthwise_weights
# ...

# %%
import numpy as np
from skimage.io import imread, imshow, imsave
import skimage.transform as transform
from skimage.transform import rescale, resize, downscale_local_mean
% matplotlib inline

# %%
img = imread('data/100023.jpg')
hub.get_expected_image_size(module)
# Out:
# [224, 224]

# %%
res_img = transform.resize(img, (224,224))
# Out:
# /usr/local/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
res_img.shape
imshow(res_img)
print(res_img)
# Out:
# /usr/local/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# [[[0.12597039 0.1937575  0.21784714]
#   [0.12244898 0.19207683 0.21064426]
#   [0.12012805 0.18903561 0.21536615]
#   ...
#   [0.13973589 0.11172469 0.10164066]
#   [0.12917167 0.10116046 0.09067627]
#   [0.14221689 0.12020808 0.10532213]]
#
#  [[0.13141257 0.19807923 0.22553021]
#   [0.12845138 0.19511805 0.22256903]
#   [0.13781513 0.20448179 0.23193277]
#   ...
#   [0.18335334 0.14813926 0.13829532]
#   [0.18487395 0.15294118 0.14005602]
#   [0.18207283 0.15078031 0.13797519]]
#
#  [[0.13837535 0.21288515 0.23641457]
#   [0.13845538 0.21296519 0.2364946 ]
#   [0.13581433 0.21032413 0.23385354]
#   ...
#   [0.18263305 0.15294118 0.13613445]
# ...

# %%
imsave('bla.png',res_img)
# Out:
# /usr/local/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
features = module(np.array([res_img]))

# %%
type(features)
# Out:
# tensorflow.python.framework.ops.Tensor

# %%
import tensorflow as tf

#define a variable to hold normal random values 

#initialize the variable
init_op = tf.global_variables_initializer()

#run the graph
with tf.Session() as sess:
    sess.run(init_op) #execute init_op
    #print the random values that we sample
    print (sess.run(features).shape)
# Out:
# (1, 1024)
